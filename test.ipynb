# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('energy.csv')
df.drop(columns = df.columns[0], axis = 1,inplace = True )

# %%
df.head()
# Out:
#   Country                Energy_type  Year  Energy_consumption  \
# 0   World           all_energy_types  1980          292.899790
# 1   World                       coal  1980           78.656134
# 2   World                natural_gas  1980           53.865223
# 3   World  petroleum_n_other_liquids  1980          132.064019
# 4   World                    nuclear  1980            7.575700
#
#    Energy_production           GDP    Population  Energy_intensity_per_capita  \
# 0         296.337228  27770.910281  4.298127e+06                    68.145921
# 1          80.114194  27770.910281  4.298127e+06                    68.145921
# 2          54.761046  27770.910281  4.298127e+06                    68.145921
# 3         133.111109  27770.910281  4.298127e+06                    68.145921
# 4           7.575700  27770.910281  4.298127e+06                    68.145921
#
#    Energy_intensity_by_GDP  CO2_emission
# 0                   10.547   4946.627130
# ...

# %%
df.shape
# Out:
# (55440, 10)

# %%
# for i in df.columns:
#     print(i,np.sum(df[i].isna()))
df.isna().sum()
# Out:
# Country                            0
# Energy_type                        0
# Year                               0
# Energy_consumption             11153
# Energy_production              11151
# GDP                            15414
# Population                      9426
# Energy_intensity_per_capita     5082
# Energy_intensity_by_GDP         5082
# CO2_emission                    3826
# dtype: int64

# %%
len(df.Energy_type.unique())
# Out:
# 6

# %%
df[df['Country']=='Vietnam']
# Out:
#        Country                Energy_type  Year  Energy_consumption  \
# 1350   Vietnam           all_energy_types  1980            0.122215
# 1351   Vietnam                       coal  1980            0.058800
# 1352   Vietnam                natural_gas  1980            0.000000
# 1353   Vietnam  petroleum_n_other_liquids  1980            0.051074
# 1354   Vietnam                    nuclear  1980                 NaN
# ...        ...                        ...   ...                 ...
# 55405  Vietnam                       coal  2019            1.647620
# 55406  Vietnam                natural_gas  2019            0.308716
# 55407  Vietnam  petroleum_n_other_liquids  2019            0.983412
# 55408  Vietnam                    nuclear  2019                 NaN
# 55409  Vietnam         renewables_n_other  2019            0.569337
#
#        Energy_production      GDP  Population  Energy_intensity_per_capita  \
# ...

# %%
240/6
# Out:
# 40.0

# %%
df.Country.unique()
# Out:
# array(['World', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antarctica', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burma', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo-Brazzaville',
#        'Congo-Kinshasa', 'Cook Islands', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Côte d’Ivoire', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
# ...

# %%
for c in df.Country.unique():
    print(c,len(df[df['Country']==c].Year.unique()))
# Out:
# World 40
# Afghanistan 40
# Albania 40
# Algeria 40
# American Samoa 40
# Angola 40
# Antarctica 40
# Antigua and Barbuda 40
# Argentina 40
# Armenia 40
# Aruba 40
# Australia 40
# Austria 40
# Azerbaijan 40
# Bahrain 40
# Bangladesh 40
# Barbados 40
# Belarus 40
# Belgium 40
# Belize 40
# Benin 40
# Bermuda 40
# Bhutan 40
# Bolivia 40
# Bosnia and Herzegovina 40
# Botswana 40
# Brazil 40
# British Virgin Islands 40
# Brunei 40
# Bulgaria 40
# Burkina Faso 40
# Burma 40
# Burundi 40
# Cabo Verde 40
# Cambodia 40
# Cameroon 40
# Canada 40
# Cayman Islands 40
# Central African Republic 40
# Chad 40
# Chile 40
# China 40
# Colombia 40
# Comoros 40
# Congo-Brazzaville 40
# Congo-Kinshasa 40
# Cook Islands 40
# Costa Rica 40
# Croatia 40
# Cuba 40
# Cyprus 40
# Czech Republic 40
# Côte d’Ivoire 40
# Denmark 40
# Djibouti 40
# Dominica 40
# Dominican Republic 40
# Ecuador 40
# Egypt 40
# El Salvador 40
# Equatorial Guinea 40
# Eritrea 40
# Estonia 40
# Eswatini 40
# Ethiopia 40
# ...

# %%
max([len(df[df['Country']==c].Year.unique()) for c in df.Country.unique()])
# Out:
# 40

# %%
df_test = df[df['Energy_type']!='nuclear']
df_test.shape
df_test = df_test[df_test['Energy_type']!='renewables_n_other']

# %%
df_test
for i in df_test.columns:
    print(i, np.sum(df_test[i].isna()))
# Out:
# Country 0
# Energy_type 0
# Year 0
# Energy_consumption 2590
# Energy_production 2588
# GDP 10276
# Population 6284
# Energy_intensity_per_capita 3388
# Energy_intensity_by_GDP 3388
# CO2_emission 3826

# %%
df_test = df_test[df_test['Year']>=2000]
df_test.shape
# Out:
# (18480, 10)

# %%
for i in df_test.columns:
    print(i, np.sum(df_test[i].isna()))
# Out:
# Country 0
# Energy_type 0
# Year 0
# Energy_consumption 678
# Energy_production 676
# GDP 2336
# Population 2300
# Energy_intensity_per_capita 1076
# Energy_intensity_by_GDP 1076
# CO2_emission 846

# %%
df_test = df_test[(~df_test['Population'].isna())]
df_test.shape
# Out:
# (16180, 10)

# %%
for i in df_test.columns:
    print(i, np.sum(df_test[i].isna()))
# Out:
# Country 0
# Energy_type 0
# Year 0
# Energy_consumption 1
# Energy_production 0
# GDP 36
# Population 0
# Energy_intensity_per_capita 400
# Energy_intensity_by_GDP 400
# CO2_emission 58

# %%
df_test.head()
df_test['Energy_intensity_per_capita'] = df_test['Energy_consumption'] * 1e6 / df_test['Population']

# %%
df_test['Energy_intensity_by_GDP'] = (df_test['Energy_consumption'] * 1e12) / (df_test['GDP'] * 1e9)

# %%
df_test.to_csv('Preprocess_Data.csv',index = None)
